# %%
import sys
# !{sys.executable} -m pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\tasli\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\tasli\anaconda3\lib\site-packages (from sklearn) (0.22)
# Requirement already satisfied: scipy>=0.17.0 in c:\users\tasli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.3.2)
# Requirement already satisfied: numpy>=1.11.0 in c:\users\tasli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.17.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\tasli\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.14.1)
# ERROR: Could not find a version that satisfies the requirement class_vis (from versions: none)
# ERROR: No matching distribution found for class_vis

# %%
#!/usr/bin/python
from class_vis import prettyPicture, output_image
from prep_terrain_data import makeTerrainData

import matplotlib.pyplot as plt
import numpy as np
import pylab as pl

#Generate data and store as training/testing data
features_train, labels_train, features_test, labels_test = makeTerrainData()

###Classify using decision tree (DT) classifer

from sklearn.tree import DecisionTreeClassifier #import the DT classifier

clf1 = DecisionTreeClassifier() #declare a DT classifier
clf1.fit(features_train, labels_train); #train the classifier
print (clf1.score (features_test, labels_test)); # print the prediction score(accuracy)
print (clf1.score (features_train, labels_train)); # print the trainig score(accuracy)

clf2 = DecisionTreeClassifier(max_depth = 50, ccp_alpha =0.05)#declare another DT with some parameter tweaking

#clf2 = DecisionTreeClassifier(min_samples_split = 50, max_depth = 5)#declare another DT with some parameter tweaking

clf2.fit(features_train, labels_train);  #train the classifier
print (clf2.score (features_test, labels_test));# print the prediction score(accuracy)
print (clf2.score (features_train, labels_train));# print the trainig score(accuracy)

#### Visulalization
prettyPicture(clf1, features_test, labels_test,"test1.png");
prettyPicture(clf2, features_test, labels_test,"test2.png");

print(clf2.get_params())
# Out:
# 0.912
# 1.0
# 0.908
# 0.9306666666666666
# {'ccp_alpha': 0.05, 'class_weight': None, 'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_impurity_split': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'presort': 'deprecated', 'random_state': None, 'splitter': 'best'}

# %%
from sklearn.datasets import load_iris
from sklearn import tree
#import a dataset
X, y = load_iris(return_X_y=True)
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, y)

#Once trained, you can plot the tree with the plot_tree function:
tree.plot_tree(clf)
# Out:
# [Text(170.9,205.737,'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(144.608,168.33,'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(197.192,168.33,'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(105.169,130.923,'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(52.5846,93.5167,'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(26.2923,56.11,'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(78.8769,56.11,'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(157.754,93.5167,'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(131.462,56.11,'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(184.046,56.11,'X[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(157.754,18.7033,'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(210.338,18.7033,'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(289.215,130.923,'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(262.923,93.5167,'X[0] <= 5.95\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(236.631,56.11,'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(289.215,56.11,'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(315.508,93.5167,'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %%
# Out:
# 0.82
